# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

model = load_model('../Model/xception_model.keras')
labels= ['Aloevera', 'Amla', 'Amruthaballi', 'Arali', 'Arjun Leaf', 'Astma_weed', 'Badipala', 'Balloon_Vine', 'Bamboo', 'Beans', 'Betel', 'Bhrami', 'Bringaraja', 'Caricature', 'Castor', 'Catharanthus', 'Chakte', 'Chilly', 'Citron lime (herelikai)', 'Coffee', 'Common rue(naagdalli)', 'Coriender', 'Curry', 'Doddpathre', 'Drumstick', 'Ekka', 'Eucalyptus', 'Ganigale', 'Ganike', 'Gasagase', 'Ginger', 'Globe Amarnath', 'Guava', 'Henna', 'Hibiscus', 'Honge', 'Insulin', 'Jackfruit', 'Jasmine', 'Kambajala', 'Kasambruga', 'Kohlrabi', 'Lantana', 'Lemon', 'Lemongrass', 'Malabar_Nut', 'Malabar_Spinach', 'Mango', 'Marigold', 'Marsh Pennywort Leaf', 'Mint', 'Neem', 'Nelavembu', 'Nerale', 'Nooni', 'Onion', 'Padri', 'Palak(Spinach)', 'Papaya', 'Parijatha', 'Pea', 'Pepper', 'Pomoegranate', 'Pumpkin', 'Raddish', 'Rose', 'Rubble Leaf', 'Sampige', 'Sapota', 'Seethaashoka', 'Seethapala', 'Spinach1', 'Tamarind', 'Taro', 'Tecoma', 'Thumbe', 'Tomato', 'Tulsi', 'Turmeric', 'ashoka', 'camphor', 'kamakasturi', 'kepala']

# %%
def get_plant_info(plant_name, file_path='../Information/plant_information.txt'):
    with open(file_path, 'r') as file:
        lines = file.read().splitlines()

    plant_info = []
    is_plant = False

    for line in lines:
        if line.strip() == plant_name:
            is_plant = True
            plant_info.append(line)
        elif is_plant:
            if '~' in line:
                break
            plant_info.append(line)

    return '\n'.join(plant_info) if plant_info else f'No information found for {plant_name}.'

# %%
img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\\manan\\Project\\Leaf dataset\\Eucalyptus\\574.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 							Plant Information:
#
# Eucalyptus
# Classification: Tree
#
# Botanical Information
# - Scientific Name: Eucalyptus globulus
# - Family: Myrtaceae
#
# Physical Characteristics
# - Eucalyptus is a fast-growing evergreen tree with narrow, lance-shaped leaves that have a distinct, aromatic scent.
# - It produces clusters of small, white, yellow, or red flowers and woody capsules containing seeds.
#
# Health Benefits
# - Eucalyptus is known for its antimicrobial, anti-inflammatory, and decongestant properties.
# - It is often used to relieve symptoms of respiratory issues such as colds, coughs, and sinusitis.
#
# Common Uses
# - The leaves are commonly used in essential oils, which are applied topically or used in aromatherapy to treat respiratory conditions.
# - Eucalyptus oil is also used in skin care products for its antiseptic properties.
#
# Cultivation Tips
# - Eucalyptus thrives in well-drained soil and prefers full sunlight.
# - The plant requires moderate watering, though it is drought-tolerant once established.
#
# Precautions
# - Eucalyptus oil should be used with caution, as it can cause skin irritation or allergic reactions in some individuals.
# - The oil should never be ingested, as it can be toxic when consumed in large amounts.

# %%
img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\manan\\Project\\Leaf dataset\\Amla\\386.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\manan\AppData\Local\Temp\ipykernel_22452\3720185183.py:2: SyntaxWarning: invalid escape sequence '\m'
#   'C:\\Users\manan\\Project\\Leaf dataset\\Amla\\386.jpg', target_size=(299, 299)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 							Plant Information:
#
# Amla
# Classification: Tree
#
# Botanical Information
# - Scientific Name: Phyllanthus emblica
# - Family: Phyllanthaceae
#
# Physical Characteristics
# - Amla is a deciduous tree with small, greenish-yellow flowers and round, green fruits that turn yellowish when ripe.
# - The fruit is small, spherical, and covered in a thin skin.
#
# Health Benefits
# - Amla is a rich source of Vitamin C and antioxidants, which help boost the immune system.
# - It is also known to improve digestion and metabolism, and is often used to promote hair growth.
# - Amla is beneficial for maintaining skin health and improving cardiovascular health.
#
# Common Uses
# - Amla is commonly used in traditional medicine and is often found in Ayurvedic products.
# - It is consumed in various forms, including as a powder, juice, or as an ingredient in jams and pickles.
#
# Cultivation Tips
# - Amla trees prefer well-drained, sandy-loamy soil and a sunny environment.
# - It requires moderate watering and benefits from occasional pruning.
#
# Precautions
# - Excessive consumption of Amla in concentrated form can lead to digestive issues or acidity.
# - Those with sensitive stomachs should use Amla with caution.

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\manan\\Project\\Leaf dataset\\Palak(Spinach)\\IMG_20201005_163315.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\manan\AppData\Local\Temp\ipykernel_22452\1369972455.py:4: SyntaxWarning: invalid escape sequence '\m'
#   'C:\\Users\manan\\Project\\Leaf dataset\\Palak(Spinach)\\IMG_20201005_163315.jpg', target_size=(299, 299)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 							Plant Information:
#
# Palak(Spinach)
# Classification: Herb
#
# Botanical Information
# - Scientific Name: Spinacia oleracea
# - Family: Amaranthaceae
#
# Physical Characteristics
# - Palak, or spinach, is a leafy green plant with dark green, tender leaves.
# - The plant grows to about 30-45 cm in height and produces small, edible seeds.
#
# Health Benefits
# - Spinach is rich in vitamins A, C, K, and folate, as well as iron, magnesium, and antioxidants, supporting eye health, immune function, and bone health.
# - It also promotes healthy digestion and heart health.
#
# Common Uses
# - Palak is widely used in cooking, particularly in curries, soups, salads, and smoothies.
# - The leaves are also used in juices for their detoxifying properties.
#
# Cultivation Tips
# - Spinach prefers cool, temperate climates and well-drained, fertile soil.
# - It requires moderate watering and should be grown in full sunlight for optimal growth.
#
# Precautions
# - Spinach should be consumed in moderation, as excessive intake can lead to kidney stones due to its oxalate content.
# - Individuals with a history of kidney issues should consult a healthcare provider before consuming spinach in large amounts.

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\manan\\Project\\Leaf dataset\\Taro\\IMG_20190921_105248.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\manan\AppData\Local\Temp\ipykernel_22452\1294454357.py:4: SyntaxWarning: invalid escape sequence '\m'
#   'C:\\Users\manan\\Project\\Leaf dataset\\Taro\\IMG_20190921_105248.jpg', target_size=(299, 299)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 							Plant Information:
#
# Taro
# Classification: Herb
#
# Botanical Information
# - Scientific Name: Colocasia esculenta
# - Family: Araceae
#
# Physical Characteristics
# - Taro is a perennial plant with large, heart-shaped leaves and thick, starchy tubers.
# - The plant grows in marshy or wetland areas and produces small, inconspicuous flowers.
#
# Health Benefits
# - Taro is rich in fiber, potassium, and vitamins C and E, supporting cardiovascular health and digestion.
# - It is also considered a good source of antioxidants that help fight inflammation.
#
# Common Uses
# - Taro is commonly cooked, boiled, or baked and is used in a variety of dishes, including soups, stews, and desserts.
# - The root is also used in flour form to make taro chips and other products.
#
# Cultivation Tips
# - Taro grows best in moist, well-drained soil and requires full sunlight.
# - Regular watering is necessary, especially in hot climates.
#
# Precautions
# - Taro should be cooked before consumption, as raw tubers contain toxic substances that can cause irritation or poisoning.

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\manan\\Project\\Leaf dataset\\Turmeric\\g.5.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\manan\AppData\Local\Temp\ipykernel_22452\3894509670.py:4: SyntaxWarning: invalid escape sequence '\m'
#   'C:\\Users\manan\\Project\\Leaf dataset\\Turmeric\\g.5.jpg', target_size=(299, 299)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 							Plant Information:
#
# Turmeric
# Classification: Herb
#
# Botanical Information
# - Scientific Name: Curcuma longa
# - Family: Zingiberaceae
#
# Physical Characteristics
# - Turmeric is a rhizomatous herb with large, green leaves and yellow-orange flowers.
# - The plant produces thick, fleshy rhizomes, which are harvested and processed into turmeric powder.
#
# Health Benefits
# - Turmeric contains curcumin, a powerful antioxidant with anti-inflammatory, anti-cancer, and antimicrobial properties.
# - It is often used for improving joint health, supporting liver function, and boosting the immune system.
#
# Common Uses
# - Turmeric is a common ingredient in cooking, especially in curry dishes and other Indian cuisine.
# - It is also used in traditional medicine for a variety of health concerns, including pain relief and digestive issues.
#
# Cultivation Tips
# - Turmeric thrives in warm, tropical climates with well-drained, loamy soil.
# - The plant requires moderate watering and a sunny environment to grow effectively.
#
# Precautions
# - Turmeric may cause stomach upset in some individuals, especially when consumed in large quantities or by those with sensitive stomachs.

# %% [markdown]
# ## Model is  working fine on the trained Data

# %% [markdown]
# ## Using new/Unknown Images for Testing

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\\manan\\Project\\Testing\\New Images\\turmeric.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 							Plant Information:
#
# Pea
# Classification: Herb
#
# Botanical Information
# - Scientific Name: Pisum sativum
# - Family: Fabaceae
#
# Physical Characteristics
# - Pea plants are climbing or bushy plants with compound leaves and small, white to purple flowers.
# - The edible part is the pod containing green, round seeds.
#
# Health Benefits
# - Peas are rich in protein, fiber, vitamins A, C, K, and folate, supporting immune function, digestive health, and bone health.
# - They also contain antioxidants and phytonutrients that promote heart health.
#
# Common Uses
# - Peas are widely used in cooking, particularly in soups, curries, salads, and as a side dish.
# - They are also used in smoothies, juices, and as a protein supplement in various dishes.
#
# Cultivation Tips
# - Peas thrive in cooler climates and prefer well-drained, fertile soil.
# - The plants require full sunlight and moderate watering, with a preference for dry soil.
#
# Precautions
# - Consuming peas in large quantities may cause bloating or gas in some individuals.
# - They should be consumed in moderation by those with kidney issues due to their purine content.

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\\manan\\Project\\Testing\\New Images\\bamboo.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 							Plant Information:
#
# Bamboo
# Classification: Grass
#
# Botanical Information
# - Scientific Name: Bambusoideae (varies by species)
# - Family: Poaceae
#
# Physical Characteristics
# - Bamboo is a fast-growing grass with hollow stems, known for its tall, woody appearance.
# - The plant has broad, lance-shaped leaves and produces small flowers that occur infrequently.
#
# Health Benefits
# - Bamboo is believed to have anti-inflammatory and antioxidant properties.
# - The young shoots are edible and can be consumed in various culinary dishes, providing dietary fiber and vitamins.
#
# Common Uses
# - Bamboo is commonly used for construction, furniture, and as a source of raw material for paper.
# - The young shoots are used in cooking, especially in Asian cuisines, and are often pickled or stir-fried.
#
# Cultivation Tips
# - Bamboo grows best in well-drained, moist soil and requires plenty of sunlight.
# - It is highly adaptable and can thrive in both tropical and temperate climates.
#
# Precautions
# - Bamboo can become invasive if not properly contained in gardens, spreading rapidly through underground rhizomes.
# - Some bamboo species can cause skin irritation when touched, so handling should be done with care.

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\\manan\\Project\\Testing\\New Images\\bamboo2.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 							Plant Information:
#
# Ginger
# Classification: Herb
#
# Botanical Information
# - Scientific Name: Zingiber officinale
# - Family: Zingiberaceae
#
# Physical Characteristics
# - Ginger is a flowering plant with green, lance-shaped leaves and yellow flowers.
# - The plantâ€™s underground rhizomes, which are thick, fleshy, and aromatic, are commonly used in cooking and medicine.
#
# Health Benefits
# - Ginger is widely known for its ability to alleviate nausea, improve digestion, and reduce inflammation.
# - It is also used to relieve pain, treat colds, and boost immunity.
#
# Common Uses
# - Fresh ginger is used in culinary dishes, beverages, and as a spice.
# - Ginger is also used in herbal medicine and in the preparation of essential oils for topical application.
#
# Cultivation Tips
# - Ginger requires warm, humid conditions and well-drained, fertile soil.
# - It thrives in partial shade and should be watered regularly without being overwatered.
#
# Precautions
# - Ginger should be used cautiously by people with blood pressure issues or those on blood-thinning medications, as it may have mild anticoagulant effects.
# - Excessive consumption of ginger may lead to digestive discomfort or heartburn.

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\\manan\\Project\\Testing\\New Images\\mango.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 							Plant Information:
#
# Mango
# Classification: Tree
#
# Botanical Information
# - Scientific Name: Mangifera indica
# - Family: Anacardiaceae
#
# Physical Characteristics
# - Mango is a large, evergreen tree with thick, dark green leaves and yellow to red flowers.
# - The fruit is oval, with a smooth, green to yellow skin and a fibrous, juicy pulp.
#
# Health Benefits
# - Mangoes are rich in vitamins A and C, fiber, and antioxidants, supporting eye health, skin health, and immune function.
# - The fruit also aids in digestion and helps maintain healthy cholesterol levels.
#
# Common Uses
# - Mangoes are eaten fresh, used in smoothies, juices, salads, and desserts.
# - The fruit is also used to make pickles, jams, and chutneys, and the leaves are sometimes used in religious rituals.
#
# Cultivation Tips
# - Mango trees prefer well-drained, sandy soil and full sunlight.
# - The trees thrive in warm, tropical climates and require minimal watering once established.
#
# Precautions
# - Mangoes may cause an allergic reaction in some individuals, particularly those sensitive to poison ivy or poison oak.
# - The fruit should be consumed in moderation due to its high sugar content.

# %%
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    'C:\\Users\\manan\\Project\\Testing\\New Images\\mango2.jpg', target_size=(299, 299)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.sigmoid(predictions[0])
predicted_label = labels[np.argmax(score)]
confidence = 100 * np.max(score)

plant_info = get_plant_info(predicted_label)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)
ax.axis('off')

plt.figtext(0.5, 0.05, f"This image most likely belongs to {predicted_label} with a {confidence:.2f}% confidence.", ha="center", va="center", fontsize=12)

plt.show()

print(f"\t\t\t\t\t\t\tPlant Information:\n\n{plant_info}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 							Plant Information:
#
# Mango
# Classification: Tree
#
# Botanical Information
# - Scientific Name: Mangifera indica
# - Family: Anacardiaceae
#
# Physical Characteristics
# - Mango is a large, evergreen tree with thick, dark green leaves and yellow to red flowers.
# - The fruit is oval, with a smooth, green to yellow skin and a fibrous, juicy pulp.
#
# Health Benefits
# - Mangoes are rich in vitamins A and C, fiber, and antioxidants, supporting eye health, skin health, and immune function.
# - The fruit also aids in digestion and helps maintain healthy cholesterol levels.
#
# Common Uses
# - Mangoes are eaten fresh, used in smoothies, juices, salads, and desserts.
# - The fruit is also used to make pickles, jams, and chutneys, and the leaves are sometimes used in religious rituals.
#
# Cultivation Tips
# - Mango trees prefer well-drained, sandy soil and full sunlight.
# - The trees thrive in warm, tropical climates and require minimal watering once established.
#
# Precautions
# - Mangoes may cause an allergic reaction in some individuals, particularly those sensitive to poison ivy or poison oak.
# - The fruit should be consumed in moderation due to its high sugar content.
